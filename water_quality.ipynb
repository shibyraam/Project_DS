# %%
#fisrt import packages and library
import pandas as pd
import numpy as np
import joblib as jb
import matplotlib.pyplot as plt
import seaborn as sns

# %%
water_qlt="water_potability.csv"
df=pd.read_csv(water_qlt) # read the csv file

# %%
df # see the csv file
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df.head(20) # see the head 20 rows
# Out:
#            ph    Hardness        Solids  Chloramines     Sulfate  \
# 0         NaN  204.890455  20791.318981     7.300212  368.516441
# 1    3.716080  129.422921  18630.057858     6.635246         NaN
# 2    8.099124  224.236259  19909.541732     9.275884         NaN
# 3    8.316766  214.373394  22018.417441     8.059332  356.886136
# 4    9.092223  181.101509  17978.986339     6.546600  310.135738
# 5    5.584087  188.313324  28748.687739     7.544869  326.678363
# 6   10.223862  248.071735  28749.716544     7.513408  393.663396
# 7    8.635849  203.361523  13672.091764     4.563009  303.309771
# 8         NaN  118.988579  14285.583854     7.804174  268.646941
# 9   11.180284  227.231469  25484.508491     9.077200  404.041635
# 10   7.360640  165.520797  32452.614409     7.550701  326.624353
# 11   7.974522  218.693300  18767.656682     8.110385         NaN
# 12   7.119824  156.704993  18730.813653     3.606036  282.344050
# ...

# %%
df.tail(20) # see the tail 20 rows
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3256   7.607224  160.565253  39184.846720     7.826411  312.056066
# 3257   6.683368  272.111698  18989.316768     5.336202  336.555100
# 3258   6.638411  180.826667   9772.504814     8.295983         NaN
# 3259   9.271355  181.259617  16540.979048     7.022499  309.238865
# 3260        NaN  134.736856   9000.025591     9.026293         NaN
# 3261   3.629922  244.187392  24856.633209     6.618071  366.967873
# 3262   8.378108  198.511213  28474.202580     6.477057  319.477187
# 3263   6.923636  260.593154  24792.525623     5.501164  332.232177
# 3264   5.893103  239.269481  20526.666156     6.349561  341.256362
# 3265   8.197353  203.105091  27701.794055     6.472914  328.886838
# 3266   8.372910  169.087052  14622.745494     7.547984         NaN
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# ...

# %%
df.info() # find the colomns dtype details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape # dataframe shape (Row & Colomns)
# Out:
# (3276, 10)

# %%
df.isnull().sum() # find null & nan values
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
# fill the nan values, ( filled in (median value) center number of values filled on nan values)

# df['ph'].fillna(df['ph'].median(), inplace=True)
# df['Sulfate'].fillna(df['Sulfate'].median(), inplace=True)
# df['Trihalomethanes'].fillna(df['Trihalomethanes'].median(), inplace=True)

# Imputing 'ph' value 

phMean_0 = df[df['Potability'] == 0]['ph'].median(skipna=True)
df.loc[(df['Potability'] == 0) & (df['ph'].isna()), 'ph'] = phMean_0
phMean_1 = df[df['Potability'] == 1]['ph'].median(skipna=True)
df.loc[(df['Potability'] == 1) & (df['ph'].isna()), 'ph'] = phMean_1

# Imputing 'Sulfate' value 

SulfateMean_0 = df[df['Potability'] == 0]['Sulfate'].median(skipna=True)
df.loc[(df['Potability'] == 0) & (df['Sulfate'].isna()), 'Sulfate'] = SulfateMean_0
SulfateMean_1 = df[df['Potability'] == 1]['Sulfate'].median(skipna=True)
df.loc[(df['Potability'] == 1) & (df['Sulfate'].isna()), 'Sulfate'] = SulfateMean_1

# Imputing 'Trihalomethanes' value 

TrihalomethanesMean_0 = df[df['Potability'] == 0]['Trihalomethanes'].median(skipna=True)
df.loc[(df['Potability'] == 0) & (df['Trihalomethanes'].isna()), 'Trihalomethanes'] = TrihalomethanesMean_0
TrihalomethanesMean_1 = df[df['Potability'] == 1]['Trihalomethanes'].median(skipna=True)
df.loc[(df['Potability'] == 1) & (df['Trihalomethanes'].isna()), 'Trihalomethanes'] = TrihalomethanesMean_1

# %%
df.isnull().sum() # again check null values
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.074069   196.369496  22014.092526     7.122277   333.544928
# std       1.470043    32.879761   8768.570828     1.583085    36.146829
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.035456   196.967627  20927.833607     7.130299   333.389426
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.405792     3.966786     0.390110
# std       80.824064        3.308162        15.769943     0.780382     0.487849
# ...

# %%
## i am find how many  0s and 1s so i am using duplicated() code

# counts0 = df[df['Potability'] == 0].duplicated().count() # how many times 0 comes

# counts1 = df[df['Potability'] == 1].duplicated().count() # how many times 0 comes

# print('0 is ',counts0,' 1 is ',counts1,' total is ',counts0+counts1 )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               3276 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          3276 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3276 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
#df['Potability'] = df['Potability'].astype('category')
# df.info()

# %%
df['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
df.shape
# Out:
# (3276, 10)

# %%
## so another number  not in here only 0 and 1 in potability colomn

# %%
# train colomns outlier boxplot
plt.figure(figsize=(7,4))
sns.boxplot(df['ph']).set_title('ph')

plt.figure(figsize=(7,4))
sns.boxplot(df['Hardness']).set_title('Hardness')

plt.figure(figsize=(7,4))
sns.boxplot(df['Solids']).set_title('Solids')

plt.figure(figsize=(7,4))
sns.boxplot(df['Chloramines']).set_title('Chloramines')

plt.figure(figsize=(7,4))
sns.boxplot(df['Sulfate']).set_title('Sulfate')

plt.figure(figsize=(7,4))
sns.boxplot(df['Conductivity']).set_title('Conductivity')

plt.figure(figsize=(7,4))
sns.boxplot(df['Organic_carbon']).set_title('Organic_carbon')

plt.figure(figsize=(7,4))
sns.boxplot(df['Trihalomethanes']).set_title('Trihalomethanes')

plt.figure(figsize=(7,4))
sns.boxplot(df['Turbidity']).set_title('Turbidity')

plt.show()

# %%
plt.figure(figsize=(8,7))
sns.heatmap(df.corr(),annot=True).set_title('water_potability')
# Out:
# Text(0.5, 1.0, 'water_potability')

# %%
# get the colomns in array wise
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder
from sklearn.svm import SVC

import warnings
warnings.filterwarnings('ignore')

# imputer= KNNImputer()
# knn_impute=imputer.fit_transform(df)

# %%
# knn_impute_colomn = imputer.get_feature_names_out()

# %%
# knn_impute_colomn

# %%
# processed csv store in this path
df.to_csv('processed_csv/processed_file.csv')

# %%
# Lable selection
data=df.copy()
X = data.drop('Potability',axis=1).copy()
y = data['Potability']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,shuffle=True, random_state=101)

# %%
svm = SVC()

# %%
svm.fit(X_train,y_train)
# Out:
# SVC()

# %%
X_train.to_csv('train/xtrain.csv',index=False)
y_train.to_csv('train/ytrain.csv',index=False)

# %%
X_test.to_csv("test/xtest.csv",index=False)
y_test.to_csv("test/ytest.csv",index=False)

# %% [markdown]
# ### Over sample handling

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
smt = SMOTE(random_state=42)
count = Counter(y_train)
print ('befor smote: ', count)
# Out:
# befor smote:  Counter({0: 1395, 1: 898})

# %%
X_train, y_train = smt.fit_resample(X_train,y_train)
count1 = Counter(y_train)
print ('after count: ', count1)
# Out:
# after count:  Counter({1: 1395, 0: 1395})

# %%
plt.figure(figsize=(10,7))
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
bestfeature = SelectKBest(score_func=chi2, k=9)
fit =  bestfeature.fit(X_train,y_train)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featurescores = pd.concat([dfcolumns,dfscores],axis=1)
featurescores.columns = ['specs','score']
print(featurescores.nlargest(9, 'score'))
# Out:
#              specs        score
# 2           Solids  4672.208565
# 4          Sulfate    11.873548
# 1         Hardness     5.372062
# 3      Chloramines     0.998415
# 6   Organic_carbon     0.399301
# 7  Trihalomethanes     0.370698
# 8        Turbidity     0.027210
# 0               ph     0.007394
# 5     Conductivity     0.002304

# %%
feature = featurescores.nlargest(9, 'score')
feature
# Out:
#              specs        score
# 2           Solids  4672.208565
# 4          Sulfate    11.873548
# 1         Hardness     5.372062
# 3      Chloramines     0.998415
# 6   Organic_carbon     0.399301
# 7  Trihalomethanes     0.370698
# 8        Turbidity     0.027210
# 0               ph     0.007394
# 5     Conductivity     0.002304

# %%
feature_list = feature['specs'].to_list()

# %%
feature_list
# Out:
# ['Solids',
#  'Sulfate',
#  'Hardness',
#  'Chloramines',
#  'Organic_carbon',
#  'Trihalomethanes',
#  'Turbidity',
#  'ph',
#  'Conductivity']

# %%
jb.dump(feature_list, 'train/model/featureselected.pkl')
# Out:
# ['train/model/featureselected.pkl']

# %%
feature_selected = X_train[feature_list]

# %%
feature_selected
# Out:
#             Solids     Sulfate    Hardness  Chloramines  Organic_carbon  \
# 0     37118.255436  253.158469  187.153617     4.600730       11.410184
# 1     15288.213774  342.447700  158.342741     7.599752        9.237118
# 2     25815.389207  297.239219  181.736389     8.534629        9.343334
# 3     11370.649169  392.841907  218.405545     6.866826       16.095520
# 4      7986.493239  419.881175  239.057680    10.365680       18.828594
# ...            ...         ...         ...          ...             ...
# 2785  21777.681056  320.312512  187.509964     7.684943       15.596315
# 2786  15758.174522  332.536743  178.881412     8.075615       15.570176
# 2787  18251.135165  328.291439  155.658088    11.344142       13.695187
# 2788  33066.796493  356.726254  180.948736     5.720035        8.227960
# 2789  25584.044743  331.838167  167.586157     7.066912       14.131215
#
#       Trihalomethanes  Turbidity        ph  Conductivity
# ...

# %%
feature_selected.to_csv('train/processed/featureselected_X_train.csv',index=False)

# %%
y_train.value_counts()
# Out:
# 1    1395
# 0    1395
# Name: Potability, dtype: int64

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
lor = LogisticRegression()
lor.fit(feature_selected,y_train)
print ('Train score is: ',lor.score(feature_selected,y_train)*100)
# Out:
# Train score is:  52.54480286738351

# %%
import joblib as jb
jb.dump(lor,'train/model/lor.pkl')
# Out:
# ['train/model/lor.pkl']

# %%
feature_selection = jb.load('train/model/featureselected.pkl')
model = jb.load('train/model/lor.pkl')
feature_selection
# Out:
# ['Solids',
#  'Sulfate',
#  'Hardness',
#  'Chloramines',
#  'Organic_carbon',
#  'Trihalomethanes',
#  'Turbidity',
#  'ph',
#  'Conductivity']

# %%
preddata = X_test

# %%
feature_selected = preddata[feature_selection]
feature_selected
# Out:
#             Solids     Sulfate    Hardness  Chloramines  Organic_carbon  \
# 2541  25363.016594  377.543291  158.318741     7.728601       13.626624
# 2605  28966.569327  333.389426  228.522860     6.179855       14.554220
# 330   24694.744205  331.838167  220.100102     8.373660        6.748092
# 515   41411.601707  310.160545  233.515043     5.895464       22.686837
# 400   37356.746401  256.473839  208.379430     8.565487        5.567693
# ...            ...         ...         ...          ...             ...
# 2200  21875.216397  408.855902  188.395023     7.141372        8.974388
# 3098  25668.198954  341.493024  179.452792     8.931531       14.062956
# 1837  26964.317181  418.494244  216.271624     6.383548       19.892680
# 1899  20509.331962  321.383278  214.731887     9.035250       12.477303
# 2466  29032.781103  326.300098  180.445051     7.301735       17.885877
#
#       Trihalomethanes  Turbidity        ph  Conductivity
# ...

# %%
y_pred = pd.DataFrame(model.predict(feature_selected))

# %%
y_pred.value_counts()
# Out:
# 0    542
# 1    441
# dtype: int64

# %% [markdown]
# ### Accuracy checking

# %%
print (classification_report(y_pred,y_test))
cm = confusion_matrix(y_pred,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.61      0.58       542
#            1       0.45      0.39      0.42       441
#
#     accuracy                           0.51       983
#    macro avg       0.50      0.50      0.50       983
# weighted avg       0.51      0.51      0.51       983

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
